# %% [markdown]
# ## Operators in SQL

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Comparison Operators

# %% [markdown]
# ![Xnip2022-07-07_23-46-44.jpg](attachment:Xnip2022-07-07_23-46-44.jpg)

# %% [markdown]
# # Logical Operators
#
# These allow us to combine multiple comparison operators.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
