# %% [markdown]
# # Keys - Primary and Foreign

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# A table can have multiple foreign keys depending on its relationships with other tables. In table below payment_id is primary key while customer_id, staff_id, rental_id r foreign keys in this table & r reference to primary keys in another table. customer_id, staff_id, rental_id r foreign keys in this table but primary keys in another table. Here since customer_id is foreign key it may be repeated many times in this table since same customer may have made multiple payments.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **FOREIGN KEY**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In above table user_id and job_id are foreign keys which reference user_id and job_id from user_account and job tables respectively.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now when u insert values in this table as user_id and job_id r decalred as foreign keys so their values u enter here will be first matched with tables of user_account and job where they r declared as primary keys. If value not present in that table, u can't make an entry here as shown below both valid insert and invalid insert cases.

# %% [markdown]
# **Valid Case**

# %% [markdown]
# As user_id=1 and job_id=2 are present in user_account and job tables which this table references hence it is a valid entry.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Invalid Case**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Constraints

# %% [markdown]
# Primary key & foreign key r type of constraints.

# %% [markdown]
# ![image.png](attachment:image.png)
